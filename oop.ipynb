# %% [markdown]
# (ch:oop)=
# # 객체 지향 프로그래밍

# %% [markdown]
# 파이썬은 객체 지향 프로그래밍(OOP)을 지원하는 언어다.
# 객체 지향 프로그래밍 언어의 가장 큰 장점 중 하나는
# 필요한 값을 생성하는 클래스를 직접 정의하여 활용할 수 있다는 점이다.
#
# 데이터 과학에서 활용되는 넘파이의 1차원 어레이에 대응하는 벡터를 값으로
# 생성하기 위한 `Vector` 클래스를 직접 정의하면서
# 클래스, 인스턴스, 객체, 생성자, 메서드 개념을 상세히 소개한다.

# %% [markdown]
# ## OOP란?

# %% [markdown]
# **객체 지향 프로그래밍**<font size='2'>Object-Oriented Programming</font>은
# 프로그램을 객체들의 상호작용으로 구성하는 프로그래밍 기법이며,
# 줄여서 보통 **OOP**라고 부른다.
# OOP를 지원하는 **객체 지향 언어**로는
# 파이썬, 자바, C++, C#, 루비, 자바스크립트 등이 있다.
#
# OOP와 대비되는 개념으로 **절차 지향 프로그래밍**이 주로 언급된다.
# 절차 지향 프로그래밍은 수행해야 할 일을 순차적인 명령과 함수 호출의 흐름으로
# 처리하는 과정을 중요하게 여기는 프로그래밍 기법이다.
# C, Pascal, Fortran 등이 절차 지향 프로그래밍 언어의 대표적인 예이다.
#
# "해야 할 일을 순차적으로 처리한다"는 표현은 가장 기초적인 프로그래밍 기법이며,
# 모든 프로그램은 원하는 결과를 얻기 위한 과정을 논리적이며 순차적으로
# 처리하도록 구현되어야 한다.
# OOP 역시 예외가 아니다.
# 하지만 OOP는 프로그램을 구성하는 객체들이 어떤 속성과 기능을 가지며
# 서로 어떻게 협력하는지를 논리적으로 묘사하는 데에 많은 방점을 둔다.

# %% [markdown]
# ## OOP와 객체

# %% [markdown]
# OOP에 대한 이해는 아래 두 가지 질문과 관련되어 있다.
#
# 1. 객체<font size='2'>object</font>란?
# 1. "객체를 중심으로 프로그래밍한다"의 의미는?

# %% [markdown]
# ### 객체란?

# %% [markdown]
# 파이썬에서 객체는 특정 클래스의 **인스턴스**<font size='2'>instance</font>로 생성된 값이다.
# 객체의 자료형은 그 객체를 생성한 클래스에 의해 결정된다.
#
# **모든 게 객체!**
#
# 파이썬의 모든 값은 객체, 즉 어떤 클래스의 인스턴스이다.
# 예를 들어 정수, 부동소수점, 부울값, 문자열, 리스트, 튜플, 사전, 집합 등은
# 각각 `int`, `float`, `bool`, `str`, `list`, `tuple`, `dict`, `set` 클래스의 인스턴스다.
# 심지어 함수, 모듈, 클래스 자체도 객체이며, 각각 `function`, `module`, `type` 클래스의 인스턴스다.
#
# | 값의 종류 | 예 | 클래스 |
# | :---: | :---: | :---: |
# | 정수 | `-2`, `0`, `17` | `int` |
# | 부동소수점 | `1.0`, `3.14` | `float` |
# | 부울값 | `True`, `False` | `bool` |
# | 문자열 | `"Hello World!"` | `str` |
# | 리스트 | `[1, 2, 3]` | `list` |
# | 튜플 | `(1, 2, 3)` | `tuple` |
# | 사전 | `{"a":1, "b":2}` | `dict` |
# | 집합 | `{1, 2, 3}` | `set` |
# | 함수 | `def f(x): return x` | `function` |
# | 모듈 | `random`, `statistics` | `module` |
# | 클래스 | `int`, `float`, `list` | `type` |

# %% [markdown]
# ### 객체 중심 프로그래밍

# %% [markdown]
# 객체는 자신이 정의할 때 사용된 클래스에서 정의된 기능을 활용할 때 객체 자신을 중심에 둔다.
# 이런 의미에서 객체 지향 프로그래밍의 핵심을 객체 중심 프로그래밍이라 할 수 있다.
#
# 예를 들어 아래 코드는 리스트에 새로운 항목을 추가하거나 삭제할 때 항상
# 리스트 객체 자신을 중심으로 이루어지도록 한다는 점을 잘 보여준다.

# %%
evens = [0, 2, 4]
odds = [1, 3, 5]

# 새로운 짝수 추가
evens.append(6)
print('새로이 짝수가 추가된 후:', evens)

# 마지막 홀수 삭제
print('삭제되는 마지막 홀수:', odds.pop())
# Out:
# 새로이 짝수가 추가된 후: [0, 2, 4, 6]
# 삭제되는 마지막 홀수: 5

# %% [markdown]
# 심지어 두 리스트의 이어붙이기 연산도 실제로는 덧셈 기호 `+` 왼쪽에 위치한 리스트를
# 중심으로 이루어진다.
#
# 예를 들어 아래 코드를 실행하면

# %%
evens + odds
# Out:
# [0, 2, 4, 6, 1, 3]

# %% [markdown]
# 파이썬은 실제로는 아래 코드를 실행한다.

# %%
evens.__add__(odds)
# Out:
# [0, 2, 4, 6, 1, 3]

# %% [markdown]
# 즉, `evens` 가 자신이 사용할 수 있는 `__add__()` 메서드를 이용하여
# `odds` 리스트를 이어붙여 새로운 리스트를 생성한다.
# `__add__()` 메서드에 대해서는 아래에서 자세히 설명한다.

# %% [markdown]
# **OOP의 핵심**
#
# OOP의 핵심은 프로그램을 객체들의 속성과 기능, 그리고 객체들 사이의 상호작용을 구성하여
# 원하는 결과를 얻는 과정을 논리적으로 표현하는 데에 있다.
#
# 이제부터 객체 생성의 필수 요소인 클래스, 인스턴스, 메서드 등을 차례대로 소개한다.

# %% [markdown]
# ## 클래스와 인스턴스

# %% [markdown]
# 데이터 과학에서 많이 활용되는 넘파이<font size='2'>NumPy</font> 라이브러리는
# 1차원 어레이<font size='2'>array</font>를 이용하여 벡터와 비슷한 값을 표현한다.
# 이번 장에서는 이와 비슷하게 작동하는 `Vector` 클래스를 직접 정의하면서
# 클래스 정의과 인스턴스 생성 과정을 살펴본다.
#
# **벡터**
#
# 벡터는 여러 개의 숫자를 순서대로 담은 값으로,
# 숫자만 담은 리스트와 비슷하게 생각할 수 있다.
# 리스트처럼 항목의 개수를 확인하거나 인덱스를 이용해 특정 항목을 꺼낼 수 있지만,
# 일반적인 리스트와 달리 벡터 덧셈, 스칼라 곱셈, 내적, 크기 계산처럼
# 숫자들의 묶음에 어울리는 수학적 연산을 지원하도록 만들 수 있다.
# 이런 차이를 하나씩 구현하면서 사용자 정의 자료형이 어떻게 만들어지는지 확인한다.

# %% [markdown]
# ### 클래스 정의

# %% [markdown]
# 클래스 정의의 기본 형식은 다음과 같다.

# %% [markdown]
# ```python
# class 클래스명:
#     # 속성과 메서드 정의
# ```

# %% [markdown]
# **`Vector` 클래스**
#
# 아래 코드에는 `Vector` 클래스가 정의되어 있다.
# `Vector` 클래스는 여러 개의 수를 항목으로 갖는 벡터 객체를 자신의 인스턴스로 생성하는 데에 사용된다.

# %%
class Vector:
    def __init__(self, components):
        self.components = tuple(float(x) for x in components)
        self.shape = (len(self.components), )

    def __repr__(self):
        return f"Vector({list(self.components)!r})"

    def __len__(self):
        return len(self.components)

    def __getitem__(self, index):
        return self.components[index]

    def __add__(self, other):
        if len(self) != len(other):
            raise ValueError("벡터의 길이가 같아야 합니다.")
        return Vector(a + b for a, b in zip(self, other))

    def __mul__(self, scalar):
        return Vector(x * scalar for x in self)

    def __rmul__(self, scalar):
        return self * scalar

    def __eq__(self, other):
        return tuple(self) == tuple(other)

    def __abs__(self):
        return sum(x * x for x in self) ** 0.5

    def to_list(self):
        return list(self.components)

    def dot(self, other):
        if len(self) != len(other):
            raise ValueError("벡터의 길이가 같아야 합니다.")
        return sum(a * b for a, b in zip(self, other))

# %% [markdown]
# `Vector` 클래스 본문에서 정의된 인스턴스 변수와 메서드는 다음과 같다.

# %% [markdown]
# **인스턴스 변수와 속성**
#
# `Vector` 클래스에서 정의된 **인스턴스 변수**<font size='2'>instance variable</font>는 다음과 같다.
# 인스턴스 변수는 객체가 생성될 때 객체 내부에 저장되는 값을 가리키는 변수이다.
# 인스턴스 변수에 할당되는 값은 클래스의 인스턴스가 생성될 때 지정되며,
# 생성된 객체의 **속성**<font size='2'>attribute</font>으로 불린다.
# 이런 의미에서 인스턴스 변수를 **속성 변수**라고 부르기도 한다.

# %% [markdown]
# | 인스턴스 변수 | 속성 |
# |---|---|
# | `self.components` | 벡터 객체의 항목을 저장하는 튜플 |
# | `self.shape` | 벡터 객체에 포함된 항목의 개수로 구성된 길이가 1인 튜플 |

# %% [markdown]
# **메서드**
#
# `Vector` 클래스에서 정의된 메서드는 다음과 같다.
# 메서드<font size='2'>method</font>는 클래스 내부에서 정의된 함수를 가리키며,
# 생성된 객체가 사용할 수 있는 기능을 제공한다.
# 메서드의 첫 번째 매개변수 `self`는 해당 메서드를 호출한 객체 자신을 가리킨다.
# `self`에 대한 자세한 설명은 아래에서 다룬다.
#
# | 메서드 | 기능 |
# |---|---|
# | `__init__()` | 생성자. 인스턴스 초기화 |
# | `__repr__()` | 객체의 공식 문자열 표현 |
# | `__len__()` | 벡터의 항목 개수 반환 |
# | `__getitem__()` | 인덱싱과 슬라이싱 지원 |
# | `__add__()` | 두 벡터의 덧셈 |
# | `__mul__()`, `__rmul__()` | 벡터와 스칼라의 곱셈 |
# | `__eq__()` | 두 벡터의 동등성 판단 |
# | `__abs__()` | 벡터의 크기 반환 |
# | `to_list()` | 벡터 항목을 리스트로 반환 |
# | `dot()` | 두 벡터의 내적 반환 |

# %% [markdown]
# **기타 변수와 함수**
#
# `Vector` 클래스에서 사용되지만 인스턴스 변수도 메서드도 아닌 이름들은 다음과 같다.
# 이 이름들은 객체의 속성이나 기능으로 저장되는 것이 아니라,
# 메서드가 실행되는 동안 값을 전달하거나 계산을 돕는 역할을 한다.
#
# | 기능 | 변수 또는 함수 |
# |---|---|
# | 매개변수 | `components`, `index`, `other`, `scalar` |
# | 지역변수 | `a`, `b`, `x` |
# | 내장 함수 | `tuple()`, `float()`, `list()`, `len()`, `zip()`, `sum()` |

# %% [markdown]
# ### 클래스의 인스턴스 정의

# %% [markdown]
# 클래스가 필요한 이유는 공통 속성과 공통 기능을 갖는
# 다양한 값을 쉽게 생성하기 위해서다.
#
# 클래스를 이용하여 생성된 값이 해당 클래스의 **인스턴스**<font size='2'>instance</font>이며,
# 특정 클래스의 인스턴스를 일반적으로 **객체**<font size='2'>object</font>라 부른다.
# 지금까지 **값**이라고 불린 대상은 실제로는 특정 클래스의 인스턴스, 즉 객체이다.
#
# 예를 들어 모든 리스트는 `list` 클래스의 인스턴스이다.
# 그리고 모든 리스트는 여러 개의 항목을 저장한다는 속성과,
# 항목의 추가와 삭제 등을 수행하는 기능, 즉 메서드를 공유한다.
# 따라서 어떤 리스트를 만들더라도 `append()`, `pop()` 같은 리스트 메서드를 같은 방식으로 사용할 수 있다.

# %% [markdown]
# **`Vector` 클래스의 인스턴스**
#
# 아래 코드에서 변수 `v`에 `Vector` 클래스의 인스턴스인 `Vector([1, 2, 3])`이 할당된다.
# `Vector([1, 2, 3])`는 리스트 `[1, 2, 3]`과 유사하지만 다르게 작동하는 벡터 객체를 가리킨다.

# %%
v = Vector([1, 2, 3])

# %% [markdown]
# `Vector([1, 2, 3])`의 자료형은 `Vector`라고 확인된다.

# %%
type(v)
# Out:
# __main__.Vector

# %% [markdown]
# 위 코드의 실행 결과에서 `__main__.Vector`의 `__main__` 현재 파일을 모듈로 가리키는 표현이다.
# 따라서 `__main__.Vector`는 현재 파일에서 사용자가 직접 정의한 `Vector` 클래스를 가리킨다.

# %% [markdown]
# **`isinstanc()` 함수**
#
# 아래 코드는 변수 `v`가 가리키는 값(객체)이 `Vector` 클래스의 인스턴스임을,
# 즉 `Vector` 자료형임을 확인해준다.

# %%
isinstance(v, Vector)
# Out:
# True

# %% [markdown]
# ## 생성자: `__init__()` 메서드

# %% [markdown]
# `Vector([1, 2, 3])` 객체 생성에 사용된 리스트 `[1, 2, 3]`은
# `Vector` 클래스의 본문에서 가장 먼저 정의된 `__init__()` 메서드의
# `components` 매개 변수의 인자로 전달된다.
#
# ```python
# def __init__(self, components):
#     self.components = tuple(float(x) for x in components)
#     self.shape = (len(self.components),)
# ```

# %% [markdown]
# **`__init__()` 메서드**
#
# 클래스의 인스턴스를 생성할 때 `__init__()` 메서드가 가장 먼저 호출되어
# 객체 생성에 필요한 준비작업을 진행한다.
# 이런 의미에서 `__init__()` 메서드를 **생성자**라고 부른다.
#
# 앞서 설명한 대로 `__init__()`는 주로 생성되는 인스턴스의
# 인스턴스 변수 선언을, 즉 생성되는 객체의 속성을 지정하는 일을 수행한다.
# 예를 들어, `Vector` 클래스의 인스턴스를 정의하는 아래 코드를 실행한다고 가정하자.
#
# ```python
# v = Vector([1, 2, 3])
# ```
#
# 그러면 파이썬 실행기는 `Vector` 클래스의 `__init__()` 메서드를 아래 형식으로 호출한다.
#
# ```python
# __init__(v, [1, 2, 3])
# ```
#
# 호출 과정에 사용되는 매개변수별 인자는 다음과 같다.
#
# - `self=v` : 생성되는 객체를 가리키는 변수
# - `self.components=[1, 2, 3]` : 벡터의 항목으로 저장될 값들로 구성된 리스트
#
# 호출된 생성자는 `self.components` 인스턴스 변수에
# 벡터에 포함될 항목들의 튜플인 `(1.0, 2.0, 3.0)`을 할당하여 저장하고,
# `self.shape`에는 생성되는 벡터의 모양을 기억하도록 한다.
#
# 아래 코드는 인스턴스 변수에 할당된 값을 확인하는 방법을 보여준다.

# %%
v = Vector([1, 2, 3])

print(f"{"Components:":11} {v.components}")
print(f"{"Shape:":11} {v.shape}")
# Out:
# Components: (1.0, 2.0, 3.0)
# Shape:      (3,)

# %% [markdown]
# **인스턴스 변수**
#
# `__init__()` 메서드는 `components` 매개변수로 전달된 값을
# `self.components`라는 변수가 가리키도록 한다.
# 반면 `self.shape` 변수는 `self.components`가 가리키는 벡터의 모양을 저장한다.
# 벡터의 모양은 항목의 개수를 이용해 `(3,)`처럼 길이가 1인 튜플로 표현된다.
#
# 이처럼 클래스 내부에서 선언되며 `self.`으로 시작하는 변수를
# **인스턴스 변수**<font size='2'>instance variable</font>라 부른다.
# 인스턴스 변수에 저장된 값은 일반적으로 `Vector([1, 2, 3])`처럼 객체를 생성할 때 지정되며,
# 앞서 설명한 대로 생성된 객체의 속성으로 객체 자체에 저장된다.
#
# 즉 `Vector([1, 2, 3])`으로 객체를 만들면
# 그 객체는 자기 안에서 `components`에는 `(1, 2, 3)`을
# `shape`에는 튜플 `(3,)`을 저장한다고 말할 수 있다.

# %% [markdown]
# **`self`의 기능**
#
# `self`는 아래 설명처럼 "지금 만들어지는 객체" 또는 "지금 메서드를 실행하는 객체"를 가리킨다.
#
# - `self.components`: 생성되는 객체 안에 저장되는 값을 가리킨다.
# - `self.shape`: 생성되는 객체 안에 저장되는 값을 가리킨다.
# - `__init__(self, components)`: 인스턴스 변수 지정 등 새로 객체 생성에 필요한 기초 작업을 진행한다.

# %% [markdown]
# **주의사항**
#
# `__init__()` 메서드의 `components` 매개변수는 메서드 외부에서 들어오는 인자를 가리키는 변수인 반면에,
# 메서드 본문에서 정의되는 `self.components`의 `components`는 매개변수로 함수 본문에 전달되는 값을
# 생성되는 객체 내부에 저장하는 기능을 수행하는 다른 변수이다.
#
# 다만, `__init__()` 메서드 본문에서 정의되는 인스턴스 변수는 관례적으로
# 매개변수와 동일한 이름으로 정의되곤 한다.

# %% [markdown]
# :::{note} 다른 언어에서의 `self`
#
# 파이썬에서는 메서드를 정의할 때 메서드를 호출한 객체를 첫 번째 매개변수로 명시한다.
# 관례적으로 이 매개변수의 이름을 `self`로 사용한다.
#
# 다른 객체 지향 언어들도 현재 객체를 가리키는 표현을 제공하지만,
# 그 방식은 언어마다 다르다.
# 예를 들어 Java, C++, C#, JavaScript 등은 메서드 내부에서 `this`를 사용하고,
# Ruby와 Swift는 `self`를 사용한다.
# Rust는 메서드 정의에서 `self`, `&self`, `&mut self`를 명시하며,
# Go는 `self`나 `this` 키워드 대신 메서드 리시버 이름을 직접 정한다.
#
# 따라서 `self`라는 이름 자체가 파이썬만의 것은 아니지만,
# 파이썬처럼 메서드의 첫 번째 매개변수 이름으로 `self`를 관례적으로 사용하는 방식은
# 파이썬의 중요한 특징 중 하나이다.
# :::

# %% [markdown]
# ## 매직 메서드

# %% [markdown]
# **매직 메서드**<font size='2'>magic methods</font>는 생성되는 클래스의 인스턴스가
# 기본적으로 갖춰야 하는 기능을 지정하는 특별한 메서드이며,
# 메서드의 이름이 밑줄 두 개로 감싸진다.
#
# 정의된 클래스에 기본으로 포함된 매직 메서드의 목록은 `dir()` 함수를 이용하여 확인할 수 있다.

# %%
dir(Vector)
# Out:
# ['__abs__',
#  '__add__',
#  '__class__',
#  '__delattr__',
#  '__dict__',
#  '__dir__',
#  '__doc__',
#  '__eq__',
#  '__firstlineno__',
#  '__format__',
#  '__ge__',
#  '__getattribute__',
#  '__getitem__',
#  '__getstate__',
#  '__gt__',
#  '__hash__',
#  '__init__',
#  '__init_subclass__',
#  '__le__',
#  '__len__',
#  '__lt__',
#  '__module__',
#  '__mul__',
#  '__ne__',
#  '__new__',
#  '__reduce__',
#  '__reduce_ex__',
#  '__repr__',
#  '__rmul__',
#  '__setattr__',
#  '__sizeof__',
#  '__static_attributes__',
#  '__str__',
#  '__subclasshook__',
#  '__weakref__',
#  'dot',
#  'to_list']

# %% [markdown]
# 모든 매직 메서드는 각자 고유한 기능을 갖는다.
# 여기서는 `Vector` 클래스를 벡터 자료형처럼 작동하도록 만들기 위해 필요한 매직 메서드 몇 개를 살펴본다.

# %% [markdown]
# ### 객체 출력

# %% [markdown]
# `v`는 항목이 3과 4인 벡터를 가리켜야 한다.
# 그런데 객체를 그대로 확인하면 기본적으로는 객체의 종류와 메모리 주소 정보가 출력된다.

# %%
print(v)

# %% [markdown]
# 사용자가 직접 만든 클래스의 객체가 더 읽기 좋은 방식으로 출력되도록 하려면
# `__repr__()` 또는 `__str__()` 메서드를 정의한다.
#
# 여기서는 객체를 다시 생성할 수 있을 만큼 명확한 문자열 표현을 제공하는 `__repr__()`을 정의한다.

# %%
class Vector:
    def __init__(self, components):
        self.components = tuple(float(x) for x in components)

    def __repr__(self):
        return f"Vector({list(self.components)!r})"


v = Vector([3, 4])
v
# Out:
# Vector([3.0, 4.0])

# %% [markdown]
# `print()` 함수도 같은 표현을 활용한다.

# %%
print(v)
# Out:
# Vector([3.0, 4.0])

# %% [markdown]
# ### 길이와 인덱싱

# %% [markdown]
# 벡터는 여러 항목을 순서대로 저장한다.
# 따라서 항목의 개수를 확인하고, 특정 위치의 항목을 조회할 수 있으면 편리하다.
#
# - `len(v)`는 `__len__()` 메서드를 호출한다.
# - `v[0]`은 `__getitem__()` 메서드를 호출한다.

# %%
class Vector:
    def __init__(self, components):
        self.components = tuple(float(x) for x in components)

    def __repr__(self):
        return f"Vector({list(self.components)!r})"

    def __len__(self):
        return len(self.components)

    def __getitem__(self, index):
        return self.components[index]


v = Vector([3, 4, 5])

# %%
print(len(v))
print(v[0])
print(v[-1])
print(v[1:])
# Out:
# 3
# 3.0
# 5.0
# (4.0, 5.0)

# %% [markdown]
# `__getitem__()` 메서드가 정의되어 있으면 `for` 반복문에서도 벡터 객체를 사용할 수 있다.

# %%
for component in v:
    print(component)
# Out:
# 3.0
# 4.0
# 5.0

# %% [markdown]
# ### 인스턴스 연산

# %% [markdown]
# 두 개의 벡터 객체를 이용하여 벡터의 덧셈이 가능한지 확인해 보자.

# %%
v = Vector([1, 2, 3])
w = Vector([10, 20, 30])

# %% [markdown]
# 아직 `+` 연산자를 지원하지 않으면 두 벡터의 덧셈은 오류가 발생한다.

# %%
try:
    v + w
except TypeError as err:
    print(type(err).__name__)
# Out:
# TypeError

# %% [markdown]
# 이유는 덧셈 연산자 `+`가 `Vector` 클래스의 인스턴스에 대해 지원되지 않기 때문이다.
# 덧셈, 곱셈 등의 연산 기호를 사용하려면 각각의 기호에 해당하는 매직 메서드를 정의해야 한다.

# %% [markdown]
# **`__add__()` 매직 메서드**
#
# 두 벡터의 덧셈은 같은 위치의 항목끼리 더하는 방식으로 정의한다.
#
# $$
# (a_1, a_2, \cdots, a_n) + (b_1, b_2, \cdots, b_n)
# = (a_1+b_1, a_2+b_2, \cdots, a_n+b_n)
# $$

# %%
class Vector:
    def __init__(self, components):
        self.components = tuple(float(x) for x in components)

    def __repr__(self):
        return f"Vector({list(self.components)!r})"

    def __len__(self):
        return len(self.components)

    def __getitem__(self, index):
        return self.components[index]

    def __add__(self, other):
        if len(self) != len(other):
            raise ValueError("벡터의 길이가 같아야 합니다.")
        return Vector(a + b for a, b in zip(self, other))


v = Vector([1, 2, 3])
w = Vector([10, 20, 30])
v + w
# Out:
# Vector([11.0, 22.0, 33.0])

# %% [markdown]
# **`__mul__()`과 `__rmul__()` 매직 메서드**
#
# 벡터와 수의 곱셈은 모든 항목에 같은 수를 곱하는 방식으로 정의한다.
# `v * 3`은 `__mul__()`을, `3 * v`는 `__rmul__()`을 사용한다.

# %%
class Vector:
    def __init__(self, components):
        self.components = tuple(float(x) for x in components)

    def __repr__(self):
        return f"Vector({list(self.components)!r})"

    def __len__(self):
        return len(self.components)

    def __getitem__(self, index):
        return self.components[index]

    def __add__(self, other):
        if len(self) != len(other):
            raise ValueError("벡터의 길이가 같아야 합니다.")
        return Vector(a + b for a, b in zip(self, other))

    def __mul__(self, scalar):
        return Vector(x * scalar for x in self)

    def __rmul__(self, scalar):
        return self * scalar


v = Vector([1, 2, 3])

print(v * 3)
print(3 * v)
# Out:
# Vector([3.0, 6.0, 9.0])
# Vector([3.0, 6.0, 9.0])

# %% [markdown]
# ### 인스턴스 동일성/동등성

# %% [markdown]
# 두 **객체의 동일성**<font size='2'>identity</font>은 두 객체가 동일한 메모리 주소에 저장되었는가에 따라 결정된다.
# 반면 두 **객체의 동등성**<font size='2'>equality</font>은 두 객체가 같은 값을 표현하는가에 따라 결정된다.

# %% [markdown]
# **동일성 판단: `is` 연산자**

# %%
v1 = Vector([1, 2])
v2 = v1
v3 = Vector([1, 2])

print(v1 is v2)
print(v1 is v3)
# Out:
# True
# False

# %% [markdown]
# **동등성 판단: `==` 연산자**
#
# 기본적으로 사용자 정의 객체의 `==`는 동일성과 비슷하게 작동한다.
# 서로 다른 객체라도 같은 항목을 갖는다면 동등하다고 판단하려면 `__eq__()` 메서드를 정의해야 한다.

# %%
print(v1 == v2)
print(v1 == v3)
# Out:
# True
# False

# %% [markdown]
# **동등성 지정: `__eq__()` 매직 메서드**

# %%
class Vector:
    def __init__(self, components):
        self.components = tuple(float(x) for x in components)

    def __repr__(self):
        return f"Vector({list(self.components)!r})"

    def __len__(self):
        return len(self.components)

    def __getitem__(self, index):
        return self.components[index]

    def __add__(self, other):
        if len(self) != len(other):
            raise ValueError("벡터의 길이가 같아야 합니다.")
        return Vector(a + b for a, b in zip(self, other))

    def __mul__(self, scalar):
        return Vector(x * scalar for x in self)

    def __rmul__(self, scalar):
        return self * scalar

    def __eq__(self, other):
        return tuple(self) == tuple(other)


v1 = Vector([1, 2])
v3 = Vector([1, 2])

print(v1 is v3)
print(v1 == v3)
# Out:
# False
# True

# %% [markdown]
# ### 크기와 참거짓

# %% [markdown]
# 벡터의 크기<font size='2'>magnitude</font>는 모든 항목의 제곱합에 제곱근을 취한 값이다.
# 파이썬에서는 `abs(v)`가 `__abs__()` 메서드를 호출한다.
#
# 또한 `bool(v)`가 `False`가 되는 경우를 영벡터로 정할 수 있다.

# %%
class Vector:
    def __init__(self, components):
        self.components = tuple(float(x) for x in components)

    def __repr__(self):
        return f"Vector({list(self.components)!r})"

    def __len__(self):
        return len(self.components)

    def __getitem__(self, index):
        return self.components[index]

    def __add__(self, other):
        if len(self) != len(other):
            raise ValueError("벡터의 길이가 같아야 합니다.")
        return Vector(a + b for a, b in zip(self, other))

    def __mul__(self, scalar):
        return Vector(x * scalar for x in self)

    def __rmul__(self, scalar):
        return self * scalar

    def __eq__(self, other):
        return tuple(self) == tuple(other)

    def __abs__(self):
        return sum(x * x for x in self) ** 0.5

    def __bool__(self):
        return bool(abs(self))


v = Vector([3, 4])
zero = Vector([0, 0])

print(abs(v))
print(bool(v))
print(bool(zero))
# Out:
# 5.0
# True
# False

# %% [markdown]
# ## 인스턴스 메서드

# %% [markdown]
# 클래스 고유의 기능은 사용자가 직접 정의한 메서드와 속성에 의해 결정된다.
# 이렇듯 사용자가 직접 정의하는 메서드를 **인스턴스 메서드**<font size='2'>instance methods</font>라 부른다.
# 인스턴스 메서드는 클래스 본문에서 정의되는 함수이며,
# 첫째 매개변수로 항상 `self`가 사용된다.
#
# 매직 메서드가 파이썬의 특별한 문법과 연결된다면,
# 일반 인스턴스 메서드는 클래스 사용자가 직접 호출하는 기능을 제공한다.

# %% [markdown]
# **예제: 리스트 변환과 내적 계산**

# %% [markdown]
# `Vector` 클래스에 다음 두 인스턴스 메서드를 추가하자.
#
# - `to_list()` : 벡터의 항목을 리스트로 반환
# - `dot()` : 두 벡터의 내적 반환
#
# 두 벡터의 내적은 같은 위치의 항목끼리 곱한 뒤 모두 더한 값이다.

# %%
class Vector:
    def __init__(self, components):
        self.components = tuple(float(x) for x in components)

    def __repr__(self):
        return f"Vector({list(self.components)!r})"

    def __len__(self):
        return len(self.components)

    def __getitem__(self, index):
        return self.components[index]

    def __add__(self, other):
        if len(self) != len(other):
            raise ValueError("벡터의 길이가 같아야 합니다.")
        return Vector(a + b for a, b in zip(self, other))

    def __mul__(self, scalar):
        return Vector(x * scalar for x in self)

    def __rmul__(self, scalar):
        return self * scalar

    def __eq__(self, other):
        return tuple(self) == tuple(other)

    def __abs__(self):
        return sum(x * x for x in self) ** 0.5

    def __bool__(self):
        return bool(abs(self))

    def to_list(self):
        return list(self.components)

    def dot(self, other):
        if len(self) != len(other):
            raise ValueError("벡터의 길이가 같아야 합니다.")
        return sum(a * b for a, b in zip(self, other))


v = Vector([1, 2, 3])
w = Vector([10, 20, 30])

print(v.to_list())
print(v.dot(w))
# Out:
# [1.0, 2.0, 3.0]
# 140.0

# %% [markdown]
# ## 예제

# %% [markdown]
# **예제 1: 좌표 이동**
#
# 2차원 위치를 벡터로 표현하면 물체의 이동을 벡터 덧셈으로 나타낼 수 있다.

# %%
position = Vector([2, 3])
move = Vector([5, -1])

new_position = position + move
print("이동 전:", position)
print("이동 후:", new_position)
# Out:
# 이동 전: Vector([2.0, 3.0])
# 이동 후: Vector([7.0, 2.0])

# %% [markdown]
# **예제 2: 속도 조절**
#
# 속도 벡터에 스칼라를 곱하면 같은 방향으로 더 빠르거나 느리게 움직이는 벡터를 만들 수 있다.

# %%
velocity = Vector([3, 4])

print("기존 속도:", velocity)
print("두 배 속도:", 2 * velocity)
print("절반 속도:", velocity * 0.5)
# Out:
# 기존 속도: Vector([3.0, 4.0])
# 두 배 속도: Vector([6.0, 8.0])
# 절반 속도: Vector([1.5, 2.0])

# %% [markdown]
# **예제 3: 두 벡터가 이루는 관계**
#
# 두 벡터의 내적은 방향의 관계를 파악할 때 사용된다.
# 예를 들어 두 벡터의 내적이 0이면 서로 직교한다.

# %%
x_axis = Vector([1, 0])
y_axis = Vector([0, 1])

print(x_axis.dot(y_axis))
# Out:
# 0.0

# %% [markdown]
# **예제 4: 가장 먼 위치 찾기**
#
# 여러 위치 벡터 중에서 원점으로부터 가장 멀리 떨어진 벡터를 찾을 수 있다.

# %%
points = [
    Vector([3, 4]),
    Vector([5, 12]),
    Vector([8, 6]),
]

farthest = max(points, key=abs)
print(farthest)
print(abs(farthest))
# Out:
# Vector([5.0, 12.0])
# 13.0

# %% [markdown]
# ## 연습문제

# %% [markdown]
# 1. `Vector([1, 2, 3])` 객체를 생성한 다음 `len()` 함수와 인덱싱을 이용하여 항목의 개수와 첫 번째 항목을 출력하라.
#
# 2. `Vector([1, 2]) + Vector([3, 4])`의 결과가 `Vector([4.0, 6.0])`으로 출력되는 이유를 `__add__()` 메서드와 연결하여 설명하라.
#
# 3. `Vector([3, 4])`에 대해 `abs()` 함수가 5.0을 반환하는 이유를 설명하라.
#
# 4. `Vector` 클래스에 `mean()` 인스턴스 메서드를 추가하라. 이 메서드는 모든 항목의 평균을 반환해야 한다.
#
# 5. `Vector` 클래스에 `is_zero()` 인스턴스 메서드를 추가하라. 모든 항목이 0이면 `True`, 아니면 `False`를 반환해야 한다.
#
# 6. `Vector([1, 2]) == Vector([1.0, 2.0])`가 `True`가 되는 이유를 `__eq__()` 메서드와 연결하여 설명하라.
#
# 7. `Vector([1, 2, 3]).dot(Vector([4, 5]))`를 실행하면 어떤 오류가 발생하는가? 왜 그런 오류가 필요한가?
#
# 8. `Vector` 클래스에 `distance_to(other)` 메서드를 추가하라. 두 벡터 사이의 거리를 반환해야 한다.
#
# 9. `Vector` 클래스에서 항목을 튜플로 저장하는 이유를 리스트로 저장하는 경우와 비교하여 설명하라.
#
# 10. `__repr__()` 메서드를 제거하면 `Vector([1, 2])` 객체의 출력이 어떻게 달라지는지 확인하라.
