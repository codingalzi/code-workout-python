# %% [markdown]
# # (연습) 문자열 1부

# %% [markdown]
# **참고**
#
# 먼저 [문자열 1부](https://codingalzi.github.io/code-workout-python/strings-part1/) 내용을 공부한 다음에 연습문제를 풀어볼 것을 권장한다.

# %% [markdown]
# ## 빈 문자열

# %% [markdown]
# ### 연습문제

# %% [markdown]
# **문제 1**
#
# 아래 코드가 `False`를 출력하는 이유를 설명하라.

# %%
print('' == ' ')
# Out:
# False

# %% [markdown]
# 답:

# %% [markdown]
# 왼쪽은 길이가 0인 빈 문자열이고, 오른쪽은 공백 문자 하나를 포함한 길이 1의 문자열이다.

# %% [markdown]
# **문제 2**
#
# 행사장 입구에서 손님에게 순번 팔찌를 나눠 준다. 빈 문자열에서 시작하여 `for` 반복문으로 `손님1 손님2 손님3 ` 형태의 안내 문구를 만들어 출력하라.

# %% [markdown]
# 답:

# %% [markdown]
# `for` 반복문과 문자열 이어붙이기 연산을 이용한다.

# %%
message = ''
for i in range(3):
    message = message + '손님' + str(i + 1) + ' '

print(message)
# Out:
# 손님1 손님2 손님3

# %% [markdown]
# ## 화이트 스페이스

# %% [markdown]
# ### 연습문제

# %% [markdown]
# **문제 1**
#
# 문자열 `'A\tB'`의 길이를 출력하라.

# %% [markdown]
# 답:

# %% [markdown]
# 탭 문자도 문자 하나로 취급된다.

# %%
print(len('A\tB'))
# Out:
# 3

# %% [markdown]
# **문제 2**
#
# 안내 데스크에서 방문자 명찰을 출력한다.
# f-문자열을 이용하여 다음과 같이 출력하는 두 줄 코드를 작성하라.
#
# ```
# Name    Time
# Ada     09:30
# ```

# %% [markdown]
# 답:

# %%
print(f'{"Name":<8}Time')
print(f'{"Ada":<8}09:30')
# Out:
# Name    Time
# Ada     09:30

# %% [markdown]
# ## 이스케이프 시퀀스

# %% [markdown]
# ### 연습문제

# %% [markdown]
# **문제 1**
#
# 작은따옴표로 감싼 문자열을 사용하여 `I'm learning Python.`을 출력하라.

# %% [markdown]
# 답:

# %%
print('I\'m learning Python.')
# Out:
# I'm learning Python.

# %% [markdown]
# **문제 2**
#
# 문자열 `C:\Users\student\notes.txt`를 출력하라.

# %% [markdown]
# 답:

# %% [markdown]
# 백슬래시 하나를 실제 문자로 넣으려면 코드에서는 `\\`처럼 두 번 적는다.

# %%
print('C:\\Users\\student\\notes.txt')
# Out:
# C:\Users\student\notes.txt

# %% [markdown]
# **문제 3**
#
# 비밀 실험실의 로그에 `경고: "door\main" 확인`이라는 문장을 남기려 한다. 따옴표와 백슬래시가 화면에 그대로 보이도록 출력하라.

# %% [markdown]
# 답:

# %%
print('경고: \"door\\main\" 확인')
# Out:
# 경고: "door\main" 확인

# %% [markdown]
# ## 날 문자열

# %% [markdown]
# ### 연습문제

# %% [markdown]
# **문제 1**
#
# 아래 두 코드의 출력 차이를 설명하라.

# %%
print('C:\new')
print(r'C:\new')
# Out:
# C:
# ew
# C:\new

# %% [markdown]
# 답:

# %% [markdown]
# 일반 문자열에서는 `\n`이 줄바꿈으로 처리될 수 있지만, 날 문자열에서는 백슬래시와 `n`이 그대로 보존된다.

# %% [markdown]
# **문제 2**
#
# 다음 코드를 실행할 때 오류가 발생하는 이유를 설명하고 대안을 제시하라.

# %%
print(r'C:\Users\student\')
# Out:
#   Cell In[92], line 1
#
#     print(r'C:\Users\student\')
#
#           ^
#
# SyntaxError: unterminated string literal (detected at line 1); perhaps you escaped the end quote?

# %% [markdown]
# 답:

# %% [markdown]
# 날 문자열도 마지막 문자를 백슬래시 하나로 끝낼 수 없다. 마지막 백슬래시가 닫는 따옴표에 영향을 주기 때문이다.
# 이런 경우엔 날 문자열대신 이스케이프 시퀀스를 활용할 수밖에 없다.

# %%
print('C:\\Users\\student\\')
# Out:
# C:\Users\student\

# %% [markdown]
# ## f-문자열 서식 지정

# %% [markdown]
# ### 연습문제

# %% [markdown]
# **문제 1**
#
# 문자열 `'hi'`를 6칸 폭에서 가운데 정렬하고, 빈 칸은 `-`로 채워 출력하라.

# %% [markdown]
# 답:

# %%
word = 'hi'
print(f'{word:-^6}')
# Out:
# --hi--

# %% [markdown]
# **문제 2**
#
# 정수 `42`를 다섯 칸 폭으로 오른쪽 정렬하고, 빈 칸은 `0`으로 채워 출력하라.

# %% [markdown]
# 답:

# %%
num = 42
print(f'{num:0>5d}')
# Out:
# 00042

# %% [markdown]
# **문제 3**
#
# 부동소수점 `-84.99888`을 소수점 아래 셋째 자리까지 출력하라.

# %% [markdown]
# 답:

# %% [markdown]
# 소수점 이하 넷째 자리에서 반올림된다.

# %%
num = -84.99888
print(f'{num:.3f}')
# Out:
# -84.999

# %% [markdown]
# **문제 4**
#
# 작은 극장의 좌석표를 출력한다. 구역 이름 `A`는 4칸 가운데 정렬하고 빈 칸은 `*`로 채운다. 가격 `12000.5`는 10칸 폭에 소수점 아래 첫째 자리까지 출력하여 한 줄로 보여라.

# %% [markdown]
# 답:

# %%
zone = 'A'
price = 12000.5

print(f'구역:{zone:*^4} 가격:{price:10.1f}')
# Out:
# 구역:*A** 가격:   12000.5
