# %% [markdown]
# # (연습) 값과 변수

# %% [markdown]
# **참고**
#
# 먼저 [값과 변수](https://codingalzi.github.io/code-workout-python/values/) 내용을 공부한 다음에 연습문제를
# 풀어볼 것을 권장한다.

# %% [markdown]
# ## 파이썬 기초 자료형

# %% [markdown]
# ### 연습문제

# %% [markdown]
# **문제 1**
#
# 다음 값들의 자료형을 예측하고 코드로 확인하라.
#
# * `-3.14`
# * `'3.14'`

# %% [markdown]
# 답:

# %%
print(type(-3.14))
print(type('3.14'))
# Out:
# <class 'float'>
# <class 'str'>

# %% [markdown]
# 설명:
#
# - `-3.14`는 부동소수점(`float`)
# - `'3.14'`는 문자열(`str`)

# %% [markdown]
# **문제 2**
#
# 강현이가 좋아하는 정수 숫자와 즐겨 먹는 과일이 각각 7과 사과이고,
# 강현이의 체중은 58.3kg이다.

# %% [markdown]
# (1) 강현이에 대한 세 가지 정보를 차례대로 항목으로 갖는 리스트를 `kgh_info` 변수에 할당하고 출력하라.

# %% [markdown]
# 답:

# %%
kgh_info = [7, '사과', 58.3]
print(kgh_info)
# Out:
# [7, '사과', 58.3]

# %% [markdown]
# (2) `kgh_info` 변수가 가리키는 리스트의 자료형이 포함된 항목의 자료형과 상관이 없음을 확인하라.

# %% [markdown]
# 답:

# %% [markdown]
# 리스트의 자료형은 포함된 항목의 자료형에 상관없이 항상 리스트(`list`)이다.
# 아래 코드는 `kgh_info`가 가리키는 리스트에 포함된 세 개의 항목은 각각 정수, 문자열, 부동소수점이지만
# 리트스 자체의 자료형은 그냥 리스트임을 확인해준다.

# %%
print(type([7, '사과', 58.3]))
# Out:
# <class 'list'>

# %% [markdown]
# 변수의 자료형은 변수가 가리키는 값의 자료형과 동일하기에 변수의 타입을 확인해도 된다.

# %%
print(type(kgh_info))
# Out:
# <class 'list'>

# %% [markdown]
# **문제 3**
#
# 아래 코드에서 정의된 `nested_list` 변수가 가리키는 값의 자료형을 확인하라.

# %%
nested_list = [1, 2, ['a', 'b', 'c']]

# %% [markdown]
# 답:

# %% [markdown]
# 앞서 설명한 대로 리스트의 자료형은 포함된 항목의 자료형과 무관하게 항상 리스트(`list`)이다.

# %%
print(type(nested_list))
# Out:
# <class 'list'>

# %% [markdown]
# ## 연산과 연산자

# %% [markdown]
# ### 연습문제

# %% [markdown]
# **문제 1**
#
# 체질량지수(BMI, Body Mass Index)는 키와 체중을 이용해 비만도를 간단히 평가하는 지표로,
# 체중(kg)을 키(m)의 제곱으로 나눈 값이다.
# 즉, 다음 식으로 체질량지수를 계산한다.
#
# ```
# BMI = 체중 ÷ (키²)
# ```
#
# 몸무게가 80kg이고 키가 1.8m인 사람의 BMI를 계산하여 다음과 같이 출력하는 코드를 작성하라.
#
# ```
# 키 1.8 m, 몸무게 80 kg인 사람의 BMI: 24.691358024691358
# ```
#
# 힌트: `weight`, `height`, `bmi` 세 개의 변수와 거듭제곱 연산자 `**`를 활용한다.

# %% [markdown]
# 답:

# %%
weight = 80
height = 1.8
bmi = weight / (height ** 2)
print("키", height, "m, 몸무게", weight, "kg인 사람의 BMI:", bmi)
# Out:
# 키 1.8 m, 몸무게 80 kg인 사람의 BMI: 24.691358024691358

# %% [markdown]
# **문제 2**
#
# 한 쌍의 변이 서로 평행한 사다리꼴의 넓이를 구하는 공식은 다음과 같다.
#
# ```
# (윗변 + 아랫변) * 높이 / 2
# ```
#
# 윗변(`top`)이 5, 아랫변(`bottom`)이 9, 높이(`height`)가 4인 사다리꼴의 넓이(`area`)를 계산하여 출력하는 코드를 작성하라.

# %% [markdown]
# 답:

# %%
top = 5
bottom = 9
height = 4
area = (top + bottom) * height / 2
print("사다리꼴의 넓이:", area)
# Out:
# 사다리꼴의 넓이: 28.0

# %% [markdown]
# ## 비교 연산자

# %% [markdown]
# ### 연습문제

# %% [markdown]
# **문제 1**
#
# 아래 내용의 논리식을 할당받는 변수 `five_seven_ge`을 선언한 후에 `five_seven_ge`에 할당된 진리값을 확인하라.
#
# ```
# 5가 7보다 크거나 같은지 여부 판단
# ```

# %% [markdown]
# 답

# %%
five_seven_ge = 5 >= 7
print(five_seven_ge)
# Out:
# False

# %% [markdown]
# **문제 2**
#
# 정수 `123`이 `3`의 배수인지 확인하는 논리식 `is_multiple_of_3`을 작성하여 실행하는 코드를 작성하라.
#
# 힌트: 어떤 수가 3의 배수라면 3으로 나눈 나머지가 0이어야 한다.

# %% [markdown]
# 답:

# %% [markdown]
# 아래 코드에서 `number`는 정수 123을, `is_multiple_of_3`는 123의 3의 배수 여부를 가리킨다.

# %%
number = 123
is_multiple_of_3 = number % 3 == 0
print(number, '의 3의 배수 여부:', is_multiple_of_3)
# Out:
# 123 의 3의 배수 여부: True

# %% [markdown]
# **문제 3**
#
# 키(신장)가 120cm 이상이어야 탑승이 가능한 놀이기구가 있다.
# 현재 키가 112cm인 어린이가 매년 2.5cm씩 자란다고 가정할 때,
# 3년 뒤에는 이 놀이기구에 탑승할 수 있는지 여부를 가리키는 변수 `can_ride`를 활용하여 판단하는 코드를 작성하라.

# %% [markdown]
# 답:

# %%
limit = 120           # 놀이기구 탑승 최소 신장(cm)
current_height = 112  # 현재 신장(cm)
growth_rate = 2.5     # 연간 신장 성장률(cm)
years = 3             # 성장 기간(년)

future_height = current_height + (growth_rate * years) # 미래 신장(cm)
can_ride = future_height >= limit                      # 탑승 가능 여부

print(can_ride)
# Out:
# False

# %% [markdown]
# ## 사전식 비교

# %% [markdown]
# ### 연습문제

# %% [markdown]
# **문제 1**
#
# 문자열로 된 숫자 `'10'`과 `'2'`의 크기를 비교하면 10이 2보다 크다는 수학적 상식과 다른 결과가 나온다.
# 그 결과를 예측하고, 왜 그런 결과가 나오는지 `ord()` 함수를 활용해 첫 글자를 비교하며 설명하라.

# %% [markdown]
# 답:

# %% [markdown]
# 문자열 비교는 첫 글자부터 비교한다. `'1'`의 코드 포인트(49)가 `'2'`의 코드 포인트(50)보다 작으므로, 문자열 `'10'`은 `'2'`보다 작다고 판단된다.

# %%
print("Ord('1') =", ord('1'))
print("Ord('2') =", ord('2'))
print("'10' < '2':", "10" < "2")
# Out:
# Ord('1') = 49
# Ord('2') = 50
# '10' < '2': True

# %% [markdown]
# **문제 2**
#
# 아래 내용의 논리식을 할당받는 변수 `Hello_hello_lt`를 선언한 후에 `Hello_hello_lt`에 할당된 진리값을 확인하라.
#
# ```
# "Hello"가 "hello" 보다 작은지 여부
# ```
#
# 참고: 두 문자열 사이의 크기비교가 가능하다. 알파벳 순서로 하며 대문자가 소문자보다 작다고 판단된다.

# %% [markdown]
# 답

# %%
Hello_hello_lt = "Hello" < "hello"
Hello_hello_lt
# Out:
# True

# %% [markdown]
# **문제 3**
#
# 리스트 `[1, 2, -100]`과 `[1, 2]`를 비교하면, 음수가 포함되어 있음에도 불구하고 앞의 리스트가 더 크다고 나온다.
# 이 현상을 리스트의 길이와 사전식 비교 원리를 들어 설명하라.

# %% [markdown]
# 답:

# %% [markdown]
# 두 리스트의 앞부분 `[1, 2]`까지는 동일하다. 이 경우 더 이상 비교할 항목이 없는 리스트보다, 항목이 남아있는(길이가 긴) 리스트가 더 크다고 판단된다. 남은 항목이 음수인지 여부는 중요하지 않다.

# %%
print([1, 2, -100] > [1, 2])
# Out:
# True

# %% [markdown]
# ## 문자열과 리스트 연산

# %% [markdown]
# ### 연습문제

# %% [markdown]
# **문제 1**
#
# 아래 표현식을 실행했을 때의 결과를 설명하라.

# %%
'3.14' + '2.71'
# Out:
# '3.142.71'

# %% [markdown]
# **답**

# %% [markdown]
# 두 개의 문자열을 단순히 이어붙인다.

# %% [markdown]
# **문제 2**
#
# 변수 `num_list`가 다음과 같이 선언된다.

# %%
num_list = [3, 6, 9, 12, 15, 18, 21]

# %% [markdown]
# (1) `num_list`의 길이를 구하라.

# %% [markdown]
# **답**

# %%
len(num_list)
# Out:
# 7

# %% [markdown]
# (2) 리스트에 포함된 `9`를 확인하는 인덱싱을 표현하는 수식을 정의하라.

# %% [markdown]
# **답**

# %%
num_list[2]
# Out:
# 9

# %% [markdown]
# (3) 리스트에 포함된 `18`을 확인하는 인덱싱을 표현하는 수식을 정의하라.

# %% [markdown]
# **답**

# %%
num_list[-2]
# Out:
# 18

# %% [markdown]
# **문제 3**
#
# 문자열 `'Python'`의 첫 글자와 마지막 글자를 서로 바꾼 새로운 문자열을 만드는 코드를 작성하라.
#
# 힌트: 인덱싱과 이어붙이기 활용

# %% [markdown]
# 답:

# %%
original = 'Python'
# 첫 글자 'P'와 마지막 글자 'n', 그리고 그 사이의 문자열을 조합
# 사이 문자열은 인덱스 1부터 4까지 직접 지정 (슬라이싱을 배우기 전이므로 인덱싱 활용)
middle = original[1] + original[2] + original[3] + original[4]
swapped = original[-1] + middle + original[0]
print(swapped)
# Out:
# nythoP

# %% [markdown]
# **문제 4**
#
# 사용자 정보가 담긴 리스트 `info`가 다음과 같이 정의된다.

# %%
info = ['name', 'age', 'phone']

# %% [markdown]
# 이 리스트가 3회 반복된 후 마지막에 `'END'` 항목이 추가된 리스트를 생성하는 코드를 작성하라.

# %% [markdown]
# 답:

# %%
info = ['name', 'age', 'phone']
result_list = info * 3 + ['END']
print(result_list)
# Out:
# ['name', 'age', 'phone', 'name', 'age', 'phone', 'name', 'age', 'phone', 'END']

# %% [markdown]
# **문제 5**
#
# 변수 `sentence`가 가리키는 문자열 `'파이썬 프로그래밍은 즐겁다'`에 문자열 `'어렵다'`가 포함되어 있지 않은지 확인하는 코드를 작성하라.
#
# 단, `not in` 연산자를 활용한다.

# %% [markdown]
# 답:

# %% [markdown]
# `not in` 연산자는 지정된 문자열이 대상 문자열에 포함되어 있지 않으면 `True`를, 포함되어 있으면 `False`를 반환한다. `'어렵다'`는 `sentence`에 없으므로 `True`가 계산된다.

# %%
sentence = '파이썬 프로그래밍은 즐겁다'
'어렵다' not in sentence
# Out:
# True

# %% [markdown]
# **문제 6**
#
# 변수 `fruits`가 가리키는 리스트 `['사과', '바나나', '포도']`에 `'오렌지'`가 포함되어 있지 않은지 확인하는 코드를 작성하라.
#
# 단, `not in` 연산자를 활용한다.

# %% [markdown]
# 답:

# %% [markdown]
# 리스트에 대해서도 `not in` 연산자는 동일하게 작동한다. `'오렌지'`는 `fruits` 리스트의 항목이 아니므로 `True`가 계산된다.

# %%
fruits = ['사과', '바나나', '포도']
'오렌지' not in fruits
# Out:
# True

# %% [markdown]
# **문제 7**
#
# 변수 `word`가 `'stressed'` 문자열을 가리킬 때, 이 단어를 거꾸로 뒤집어 `'desserts'`로 출력하는 코드를 작성하라.
# 단, 문자열의 각 문자를 음수를 이용하여 인덱싱하여 이어붙여야 한다.

# %% [markdown]
# 답:

# %%
word = 'stressed'
reversed_word = word[-1] + word[-2] + word[-3] + word[-4] + word[-5] + word[-6] + word[-7] + word[-8]
print(reversed_word)
# Out:
# desserts

# %% [markdown]
# ## 연산자 우선순위

# %% [markdown]
# ### 연습문제

# %% [markdown]
# **문제 1**
#
# 다음 수식의 계산 결과를 예측하고, 연산 순서를 괄호 `()`를 사용하여 그 이유를 설명하라

# %%
7 + 3 * 2 ** 2 == 7 + (3 * (2 ** 2))
# Out:
# True

# %% [markdown]
# 답:

# %% [markdown]
# 결과는 `True`이다.
# 이유는 동치 비교 연산자의 좌우 모두 19로 계산되기 때문이다.
#
# - 연산 순서는 거듭제곱(`**`) $\rightarrow$ 곱셈(`*`) $\rightarrow$ 덧셈(`+`) 순이다.
# - 따라서 `7 + 3 * 2 ** 2`를 괄호로 표현하면 `7 + (3 * (2 ** 2))`이 된다.

# %%
7 + 3 * 2 ** 2 == 7 + (3 * (2 ** 2))
# Out:
# True

# %% [markdown]
# **문제 2**
#
# 문자열 `'A'`와 `'B'`를 이용하여 `'ABBB'`가 아닌 `'ABABAB'`를 출력하려면 아래 코드에 어떻게 괄호를 추가해야 하는가?

# %%
'A' + 'B' * 3
# Out:
# 'ABBB'

# %% [markdown]
# 답:

# %% [markdown]
# 덧셈(이어붙이기)을 먼저 수행하도록 괄호로 감싸야 한다.

# %%
('A' + 'B') * 3
# Out:
# 'ABABAB'

# %% [markdown]
# **문제 3**
#
# 아래 코드의 실행 결과를 예측하고 이유를 설명하라.
#
# ```python
# x = 10
# x < 5 * 3
# ```

# %% [markdown]
# 답:

# %% [markdown]
# 결과는 `True`이다.
# 우변의 곱셈 `5 * 3`이 먼저 계산되어 15가 되고, 그 후 `10 < 15` 비교 연산이 수행된다.

# %%
x = 10
print(x < 5 * 3)
# Out:
# True

# %% [markdown]
# **문제 4**
#
# 리스트 `data = [10, 20, 30]`이 주어졌을 때, 첫 번째 항목과 두 번째 항목의 평균을 구하는 코드를 작성하라.
# 단, 괄호를 적절히 사용하여 우선순위를 제어해야 한다.

# %% [markdown]
# 답:

# %%
data = [10, 20, 30]
average = (data[0] + data[1]) / 2
print(average)
# Out:
# 15.0

# %% [markdown]
# 덧셈을 먼저 수행하기 위해 분자를 괄호로 감싸야 한다.
# 만약 괄호를 쓰지 않고 `data[0] + data[1] / 2`라고 쓰면 나눗셈이 먼저 수행되어 `10 + 10.0` 즉, 20.0이 되어 오답이 된다.

# %%
data = [10, 20, 30]
average = data[0] + data[1] / 2
print(average)
# Out:
# 20.0

# %% [markdown]
# **문제 5**
#
# 지수는 친구 3명(본인 포함 총 4명)과 함께 배달 음식을 시켜 먹었다.
# 피자 가격은 25,000원, 치킨 가격은 19,000원이었고 이를 4명이 똑같이 나눠 내기로 했다.
# 지수가 계산기로 아래와 같이 계산하여 1인당 29,750원을 달라고 하자 친구들이 너무 비싸다며 깜짝 놀랐다.

# %%
25000 + 19000 / 4
# Out:
# 29750.0

# %% [markdown]
# (1) 지수의 위 계산식이 실제로 어떤 의미로 계산되었는지 설명하라.

# %% [markdown]
# 답:

# %% [markdown]
# 나눗셈(`/`)이 덧셈(`+`)보다 먼저 계산되므로, 치킨 값(19,000)만 4로 나누고 그 결과(4,750)에 피자 값(25,000)을 통째로 더해버렸다.

# %% [markdown]
# (2) 1인당 내야 할 올바른 금액을 구하는 파이썬 코드를 작성하여 실행하라.

# %% [markdown]
# 답:

# %% [markdown]
# 전체 음식 값을 괄호로 묶어 먼저 더해야 한다.
# 그러면 올바른 1인당 금액은 11,000원이 된다.

# %%
(25000 + 19000) / 4
# Out:
# 11000.0
